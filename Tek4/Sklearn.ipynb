# %% [markdown]
# Sinh dữ liệu Gaussian

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import pandas as pd

# %%
X,y = make_blobs(n_samples=100,centers=3,n_features=2)

df=pd.DataFrame(dict(x=X[:,0], y=X[:,1],label=y))
colors={0:'red',1:'blue',2:'green'}
fig,ax=plt.subplots()
grouped=df.groupby('label')

for key,group in grouped:
    group.plot(ax=ax,kind='scatter',x='x',y='y',label=key,color=colors[key])

# %% [markdown]
# Sinh dữ liệu hình vòng cung

# %%
from sklearn.datasets import make_moons
X,y=make_moons(n_samples=100,noise=0.08)

df=pd.DataFrame(dict(x=X[:,0],y=X[:,1],label=y))
color={0:'red',1:'blue'}
fig,ax=plt.subplots()
grouped=df.groupby('label')

for key,group in grouped:
    group.plot(ax=ax,kind='scatter',x='x',y='y',label=key,color=colors[key])

# %%
from sklearn.datasets import make_circles
X,y = make_circles(n_samples=100,noise=0.1)
df=pd.DataFrame(dict(x=X[:,0],y=X[:,1],label=y))
colors={0:'red',1:'green'}
grouped=df.groupby('label')
fig,ax= plt.subplots()
for key,group in grouped:
    group.plot(ax=ax,kind='scatter',x='x',y='y',label=key,color=colors[key])

# %% [markdown]
# Sinh dữ liệu bài toán hồi quy

# %%
from sklearn.datasets import make_regression

X,y= make_regression(n_samples=100,n_features=1,noise=2)

plt.scatter(X,y)
dictcol={
    'x':[X[:]],
    'y':[y[:]]
    
}
df=pd.DataFrame(dictcol)
df
# Out:
#                                                    x  \
# 0  [[-1.6531721077197177], [-1.237550532121149], ...
#
#                                                    y
# 0  [-30.460834053071423, -22.321828686254698, 2.7...
