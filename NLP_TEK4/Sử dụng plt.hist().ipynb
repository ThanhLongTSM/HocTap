# %%
from nltk.tokenize import TweetTokenizer,regexp_tokenize
ht = '#xinchaovn'
# Định nghĩa pattern1
pattern1 = '#\w+'
# Sử dụng pattern1  trên tweet đầu tiên trong danh sách tweet
hashtags = regexp_tokenize(ht[0], pattern1)
# pattern2 = ([__]\w+)
# # Sử dụng pattern2 trên tweet cuối cùng trong danh sách tweet
# mentions_hashtags = ____(____[__], ____)
# # Use the TweetTokenizer to tokenize all tweets into one list
# tknzr = ____
# all_tokens = [____(_) for t in tweets]
print(hashtags)
# Out:
# []

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist([1, 5, 5, 7, 7, 7, 9])
# Out:
# (array([1., 0., 0., 0., 0., 2., 0., 3., 0., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
from nltk.tokenize import word_tokenize

# %%
word = 'Hello My name is Long, how are you today'
word=word_tokenize(word)
print(word)
word_length = [len(w) for w in word]
print(word_length)
plt.hist(word_length)
# Out:
# ['Hello', 'My', 'name', 'is', 'Long', ',', 'how', 'are', 'you', 'today']
# [5, 2, 4, 2, 4, 1, 3, 3, 3, 5]
# (array([1., 0., 2., 0., 0., 3., 0., 2., 0., 2.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)
