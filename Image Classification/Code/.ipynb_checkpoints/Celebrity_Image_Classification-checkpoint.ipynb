# %% [markdown]
# ### Import library

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
path_to_data = './data/raw picture/'
path_to_cr_data = './data/cropped/'

# %%
import os
img_dirs=[]
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
img_dirs
# Out:
# ['./data/raw picture/Barack_Obama',
#  './data/raw picture/C_Ronaldo',
#  './data/raw picture/Donald_Trump',
#  './data/raw picture/Elizabeth_Olsen',
#  './data/raw picture/Gal_Gadot',
#  './data/raw picture/Jennifer_Lawrence',
#  './data/raw picture/Lionel_Messi']

# %%
#remove path of directory if it exits, make new directory data
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Barack_Obama
# Generating cropped images in folder:  ./data/cropped/Barack_Obama
# C_Ronaldo
# Generating cropped images in folder:  ./data/cropped/C_Ronaldo
# Donald_Trump
# Generating cropped images in folder:  ./data/cropped/Donald_Trump
# Elizabeth_Olsen
# Generating cropped images in folder:  ./data/cropped/Elizabeth_Olsen
# Gal_Gadot
# Generating cropped images in folder:  ./data/cropped/Gal_Gadot
# Jennifer_Lawrence
# Generating cropped images in folder:  ./data/cropped/Jennifer_Lawrence
# Lionel_Messi
# Generating cropped images in folder:  ./data/cropped/Lionel_Messi

# %%
celebrity_file_names_dict
# Out:
# {'Barack_Obama': ['./data/cropped/Barack_Obama/Barack_Obama1.png',
#   './data/cropped/Barack_Obama/Barack_Obama2.png',
#   './data/cropped/Barack_Obama/Barack_Obama3.png',
#   './data/cropped/Barack_Obama/Barack_Obama4.png',
#   './data/cropped/Barack_Obama/Barack_Obama5.png',
#   './data/cropped/Barack_Obama/Barack_Obama6.png',
#   './data/cropped/Barack_Obama/Barack_Obama7.png',
#   './data/cropped/Barack_Obama/Barack_Obama8.png',
#   './data/cropped/Barack_Obama/Barack_Obama9.png',
#   './data/cropped/Barack_Obama/Barack_Obama10.png',
#   './data/cropped/Barack_Obama/Barack_Obama11.png',
#   './data/cropped/Barack_Obama/Barack_Obama12.png',
#   './data/cropped/Barack_Obama/Barack_Obama13.png',
#   './data/cropped/Barack_Obama/Barack_Obama14.png',
#   './data/cropped/Barack_Obama/Barack_Obama15.png',
#   './data/cropped/Barack_Obama/Barack_Obama16.png',
#   './data/cropped/Barack_Obama/Barack_Obama17.png',
#   './data/cropped/Barack_Obama/Barack_Obama18.png',
#   './data/cropped/Barack_Obama/Barack_Obama19.png',
#   './data/cropped/Barack_Obama/Barack_Obama20.png',
#   './data/cropped/Barack_Obama/Barack_Obama21.png',
#   './data/cropped/Barack_Obama/Barack_Obama22.png',
#   './data/cropped/Barack_Obama/Barack_Obama23.png',
#   './data/cropped/Barack_Obama/Barack_Obama24.png',
#   './data/cropped/Barack_Obama/Barack_Obama25.png',
#   './data/cropped/Barack_Obama/Barack_Obama26.png',
#   './data/cropped/Barack_Obama/Barack_Obama27.png',
#   './data/cropped/Barack_Obama/Barack_Obama28.png',
#   './data/cropped/Barack_Obama/Barack_Obama29.png',
#   './data/cropped/Barack_Obama/Barack_Obama30.png',
#   './data/cropped/Barack_Obama/Barack_Obama31.png',
#   './data/cropped/Barack_Obama/Barack_Obama32.png',
#   './data/cropped/Barack_Obama/Barack_Obama33.png',
#   './data/cropped/Barack_Obama/Barack_Obama34.png',
#   './data/cropped/Barack_Obama/Barack_Obama35.png',
#   './data/cropped/Barack_Obama/Barack_Obama36.png',
#   './data/cropped/Barack_Obama/Barack_Obama37.png',
#   './data/cropped/Barack_Obama/Barack_Obama38.png',
#   './data/cropped/Barack_Obama/Barack_Obama39.png',
#   './data/cropped/Barack_Obama/Barack_Obama40.png',
#   './data/cropped/Barack_Obama/Barack_Obama41.png',
#   './data/cropped/Barack_Obama/Barack_Obama42.png',
#   './data/cropped/Barack_Obama/Barack_Obama43.png',
#   './data/cropped/Barack_Obama/Barack_Obama44.png',
#   './data/cropped/Barack_Obama/Barack_Obama45.png',
#   './data/cropped/Barack_Obama/Barack_Obama46.png',
#   './data/cropped/Barack_Obama/Barack_Obama47.png',
#   './data/cropped/Barack_Obama/Barack_Obama48.png',
#   './data/cropped/Barack_Obama/Barack_Obama49.png',
#   './data/cropped/Barack_Obama/Barack_Obama50.png',
#   './data/cropped/Barack_Obama/Barack_Obama51.png',
#   './data/cropped/Barack_Obama/Barack_Obama52.png',
#   './data/cropped/Barack_Obama/Barack_Obama53.png',
#   './data/cropped/Barack_Obama/Barack_Obama54.png',
#   './data/cropped/Barack_Obama/Barack_Obama55.png',
#   './data/cropped/Barack_Obama/Barack_Obama56.png',
#   './data/cropped/Barack_Obama/Barack_Obama57.png',
#   './data/cropped/Barack_Obama/Barack_Obama58.png',
#   './data/cropped/Barack_Obama/Barack_Obama59.png'],
#  'C_Ronaldo': ['./data/cropped/C_Ronaldo/C_Ronaldo1.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo2.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo3.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo4.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo5.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo6.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo7.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo8.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo9.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo10.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo11.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo12.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo13.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo14.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo15.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo16.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo17.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo18.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo19.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo20.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo21.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo22.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo23.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo24.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo25.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo26.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo27.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo28.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo29.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo30.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo31.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo32.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo33.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo34.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo35.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo36.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo37.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo38.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo39.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo40.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo41.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo42.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo43.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo44.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo45.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo46.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo47.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo48.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo49.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo50.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo51.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo52.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo53.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo54.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo55.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo56.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo57.png',
#   './data/cropped/C_Ronaldo/C_Ronaldo58.png'],
#  'Donald_Trump': ['./data/cropped/Donald_Trump/Donald_Trump1.png',
#   './data/cropped/Donald_Trump/Donald_Trump2.png',
#   './data/cropped/Donald_Trump/Donald_Trump3.png',
#   './data/cropped/Donald_Trump/Donald_Trump4.png',
#   './data/cropped/Donald_Trump/Donald_Trump5.png',
#   './data/cropped/Donald_Trump/Donald_Trump6.png',
#   './data/cropped/Donald_Trump/Donald_Trump7.png',
#   './data/cropped/Donald_Trump/Donald_Trump8.png',
#   './data/cropped/Donald_Trump/Donald_Trump9.png',
png',
#   './data/cropped/Jennifer_Lawrence/Jennifer_Lawrence81.png',
#   './data/cropped/Jennifer_Lawrence/Jennifer_Lawrence82.png',
#   './data/cropped/Jennifer_Lawrence/Jennifer_Lawrence83.png'],
#  'Lionel_Messi': ['./data/cropped/Lionel_Messi/Lionel_Messi1.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi2.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi3.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi4.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi5.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi6.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi7.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi8.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi9.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi10.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi11.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi12.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi13.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi14.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi15.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi16.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi17.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi18.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi19.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi20.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi21.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi22.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi23.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi24.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi25.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi26.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi27.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi28.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi29.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi30.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi31.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi32.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi33.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi34.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi35.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi36.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi37.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi38.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi39.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi40.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi41.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi42.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi43.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi44.png',
#   './data/cropped/Lionel_Messi/Lionel_Messi45.png']}

# %% [markdown]
# ## Wavelet transform

# %%
import numpy as np
import pywt
import cv2

def w2d(img, mode = 'haar',level = 1):
    imArray = img
    
    imArray = cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY)
    imArray = np.float32(imArray)
    imArray /=255
    
    coeffs = pywt.wavedec2(imArray,mode,level = level)
    
    coeffs_H = list(coeffs)
    coeffs_H[0] *=0
    
    imArray_H= pywt.waverec2(coeffs_H,mode);
    imArray_H *=255
    imArray_H = np.uint8(imArray_H)
    
    return imArray_H

# %%
cropped_img = cv2.imread('./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen18.png')
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har,cmap='gray')

# %%
class_dict = {}
count =0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count+=1
class_dict
# Out:
# {'Barack_Obama': 0,
#  'C_Ronaldo': 1,
#  'Donald_Trump': 2,
#  'Elizabeth_Olsen': 3,
#  'Gal_Gadot': 4,
#  'Jennifer_Lawrence': 5,
#  'Lionel_Messi': 6}

# %%
for a in celebrity_file_names_dict.values():
    for x in a:
        print (x)
# Out:
# ./data/cropped/Barack_Obama/Barack_Obama1.png
# ./data/cropped/Barack_Obama/Barack_Obama2.png
# ./data/cropped/Barack_Obama/Barack_Obama3.png
# ./data/cropped/Barack_Obama/Barack_Obama4.png
# ./data/cropped/Barack_Obama/Barack_Obama5.png
# ./data/cropped/Barack_Obama/Barack_Obama6.png
# ./data/cropped/Barack_Obama/Barack_Obama7.png
# ./data/cropped/Barack_Obama/Barack_Obama8.png
# ./data/cropped/Barack_Obama/Barack_Obama9.png
# ./data/cropped/Barack_Obama/Barack_Obama10.png
# ./data/cropped/Barack_Obama/Barack_Obama11.png
# ./data/cropped/Barack_Obama/Barack_Obama12.png
# ./data/cropped/Barack_Obama/Barack_Obama13.png
# ./data/cropped/Barack_Obama/Barack_Obama14.png
# ./data/cropped/Barack_Obama/Barack_Obama15.png
# ./data/cropped/Barack_Obama/Barack_Obama16.png
# ./data/cropped/Barack_Obama/Barack_Obama17.png
# ./data/cropped/Barack_Obama/Barack_Obama18.png
# ./data/cropped/Barack_Obama/Barack_Obama19.png
# ./data/cropped/Barack_Obama/Barack_Obama20.png
# ./data/cropped/Barack_Obama/Barack_Obama21.png
# ./data/cropped/Barack_Obama/Barack_Obama22.png
# ./data/cropped/Barack_Obama/Barack_Obama23.png
# ./data/cropped/Barack_Obama/Barack_Obama24.png
# ./data/cropped/Donald_Trump/Donald_Trump8.png
# ./data/cropped/Donald_Trump/Donald_Trump9.png
# ./data/cropped/Donald_Trump/Donald_Trump10.png
# ./data/cropped/Donald_Trump/Donald_Trump11.png
# ./data/cropped/Donald_Trump/Donald_Trump12.png
# ./data/cropped/Donald_Trump/Donald_Trump13.png
# ./data/cropped/Donald_Trump/Donald_Trump14.png
# ./data/cropped/Donald_Trump/Donald_Trump15.png
# ./data/cropped/Donald_Trump/Donald_Trump16.png
# ./data/cropped/Donald_Trump/Donald_Trump17.png
# ./data/cropped/Donald_Trump/Donald_Trump18.png
# ./data/cropped/Donald_Trump/Donald_Trump19.png
# ./data/cropped/Donald_Trump/Donald_Trump20.png
# ./data/cropped/Donald_Trump/Donald_Trump21.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen1.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen2.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen3.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen4.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen5.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen6.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen7.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen8.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen9.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen10.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen11.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen12.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen13.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen14.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen15.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen16.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen17.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen18.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen19.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen20.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen21.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen22.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen23.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen24.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen25.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen26.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen27.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen28.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen29.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen30.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen31.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen32.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen33.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen34.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen35.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen36.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen37.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen38.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen39.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen40.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen41.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen42.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen43.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen44.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen45.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen46.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen47.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen48.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen49.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen50.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen51.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen52.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen53.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen54.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen55.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen56.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen57.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen58.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen59.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen60.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen61.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen62.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen63.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen64.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen65.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen66.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen67.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen68.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen69.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen70.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen71.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen72.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen73.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen74.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen75.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen76.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen77.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen78.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen79.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen80.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen81.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen82.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen83.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen84.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen85.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen86.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen87.png
# ./data/cropped/Elizabeth_Olsen/Elizabeth_Olsen88.png
# ./data/cropped/Gal_Gadot/Gal_Gadot1.png
# ./data/cropped/Gal_Gadot/Gal_Gadot2.png
# ./data/cropped/Gal_Gadot/Gal_Gadot3.png
# ./data/cropped/Gal_Gadot/Gal_Gadot4.png
# ./data/cropped/Gal_Gadot/Gal_Gadot5.png
# ./data/cropped/Gal_Gadot/Gal_Gadot6.png
# ./data/cropped/Gal_Gadot/Gal_Gadot7.png
# ./data/cropped/Gal_Gadot/Gal_Gadot8.png
# ./data/cropped/Gal_Gadot/Gal_Gadot9.png
# ./data/cropped/Gal_Gadot/Gal_Gadot10.png
# ./data/cropped/Gal_Gadot/Gal_Gadot11.png
# ./data/cropped/Gal_Gadot/Gal_Gadot12.png
# ./data/cropped/Gal_Gadot/Gal_Gadot13.png
# ./data/cropped/Gal_Gadot/Gal_Gadot14.png
# ./data/cropped/Gal_Gadot/Gal_Gadot15.png
# ./data/cropped/Gal_Gadot/Gal_Gadot16.png
# ./data/cropped/Gal_Gadot/Gal_Gadot17.png
# ./data/cropped/Gal_Gadot/Gal_Gadot18.png
# ./data/cropped/Gal_Gadot/Gal_Gadot19.png
# ./data/cropped/Gal_Gadot/Gal_Gadot20.png
# ./data/cropped/Gal_Gadot/Gal_Gadot21.png
# ./data/cropped/Gal_Gadot/Gal_Gadot22.png
# ./data/cropped/Gal_Gadot/Gal_Gadot23.png
# ./data/cropped/Gal_Gadot/Gal_Gadot24.png
# ./data/cropped/Gal_Gadot/Gal_Gadot25.png
# ./data/cropped/Gal_Gadot/Gal_Gadot26.png
# ./data/cropped/Gal_Gadot/Gal_Gadot27.png
# ./data/cropped/Gal_Gadot/Gal_Gadot28.png
# ./data/cropped/Gal_Gadot/Gal_Gadot29.png
# ./data/cropped/Gal_Gadot/Gal_Gadot30.png
# ./data/cropped/Gal_Gadot/Gal_Gadot31.png
# ./data/cropped/Gal_Gadot/Gal_Gadot32.png
# ./data/cropped/Gal_Gadot/Gal_Gadot33.png
# ./data/cropped/Gal_Gadot/Gal_Gadot34.png
# ./data/cropped/Gal_Gadot/Gal_Gadot35.png
# ./data/cropped/Gal_Gadot/Gal_Gadot36.png
# ./data/cropped/Gal_Gadot/Gal_Gadot37.png
# ./data/cropped/Gal_Gadot/Gal_Gadot38.png
# ./data/cropped/Gal_Gadot/Gal_Gadot39.png
# ./data/cropped/Gal_Gadot/Gal_Gadot40.png
# ./data/cropped/Gal_Gadot/Gal_Gadot41.png
# ./data/cropped/Gal_Gadot/Gal_Gadot42.png
# ./data/cropped/Gal_Gadot/Gal_Gadot43.png
# ./data/cropped/Gal_Gadot/Gal_Gadot44.png
# ./data/cropped/Gal_Gadot/Gal_Gadot45.png
# ./data/cropped/Gal_Gadot/Gal_Gadot46.png
# ./data/cropped/Gal_Gadot/Gal_Gadot47.png
# ./data/cropped/Gal_Gadot/Gal_Gadot48.png
# ./data/cropped/Gal_Gadot/Gal_Gadot49.png
# ./data/cropped/Gal_Gadot/Gal_Gadot50.png
# ./data/cropped/Gal_Gadot/Gal_Gadot51.png
# ./data/cropped/Gal_Gadot/Gal_Gadot52.png
# ./data/cropped/Gal_Gadot/Gal_Gadot53.png
# ./data/cropped/Gal_Gadot/Gal_Gadot54.png
# ./data/cropped/Gal_Gadot/Gal_Gadot55.png
# ./data/cropped/Gal_Gadot/Gal_Gadot56.png
# ./data/cropped/Gal_Gadot/Gal_Gadot57.png
# ./data/cropped/Gal_Gadot/Gal_Gadot58.png
# ./data/cropped/Gal_Gadot/Gal_Gadot59.png
# ./data/cropped/Gal_Gadot/Gal_Gadot60.png
# ./data/cropped/Gal_Gadot/Gal_Gadot61.png
# ./data/cropped/Gal_Gadot/Gal_Gadot62.png
# ./data/cropped/Gal_Gadot/Gal_Gadot63.png
# ./data/cropped/Gal_Gadot/Gal_Gadot64.png
# ./data/cropped/Gal_Gadot/Gal_Gadot65.png
# ./data/cropped/Gal_Gadot/Gal_Gadot66.png
# ./data/cropped/Gal_Gadot/Gal_Gadot67.png
# ./data/cropped/Gal_Gadot/Gal_Gadot68.png
# ./data/cropped/Gal_Gadot/Gal_Gadot69.png
# ./data/cropped/Gal_Gadot/Gal_Gadot70.png
# ./data/cropped/Gal_Gadot/Gal_Gadot71.png
# ./data/cropped/Gal_Gadot/Gal_Gadot72.png
# ./data/cropped/Gal_Gadot/Gal_Gadot73.png
# ./data/cropped/Gal_Gadot/Gal_Gadot74.png
# ./data/cropped/Gal_Gadot/Gal_Gadot75.png
# ./data/cropped/Gal_Gadot/Gal_Gadot76.png
# ./data/cropped/Gal_Gadot/Gal_Gadot77.png
# ./data/cropped/Gal_Gadot/Gal_Gadot78.png
# ./data/cropped/Gal_Gadot/Gal_Gadot79.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence1.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence2.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence3.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence4.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence5.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence6.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence7.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence8.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence9.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence10.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence11.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence12.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence13.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence14.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence15.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence16.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence17.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence18.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence19.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence20.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence21.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence22.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence23.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence24.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence25.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence26.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence27.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence28.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence29.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence30.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence31.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence32.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence33.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence34.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence35.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence36.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence37.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence38.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence39.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence40.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence41.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence42.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence43.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence44.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence45.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence46.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence47.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence48.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence49.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence50.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence51.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence52.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence53.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence54.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence55.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence56.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence57.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence58.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence59.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence60.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence61.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence62.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence63.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence64.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence65.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence66.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence67.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence68.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence69.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence70.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence71.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence72.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence73.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence74.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence75.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence76.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence77.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence78.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence79.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence80.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence81.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence82.png
# ./data/cropped/Jennifer_Lawrence/Jennifer_Lawrence83.png
# ./data/cropped/Lionel_Messi/Lionel_Messi1.png
# ./data/cropped/Lionel_Messi/Lionel_Messi2.png
# ./data/cropped/Lionel_Messi/Lionel_Messi3.png
# ./data/cropped/Lionel_Messi/Lionel_Messi4.png
# ./data/cropped/Lionel_Messi/Lionel_Messi5.png
# ./data/cropped/Lionel_Messi/Lionel_Messi6.png
# ./data/cropped/Lionel_Messi/Lionel_Messi7.png
# ./data/cropped/Lionel_Messi/Lionel_Messi8.png
# ./data/cropped/Lionel_Messi/Lionel_Messi9.png
# ./data/cropped/Lionel_Messi/Lionel_Messi10.png
# ./data/cropped/Lionel_Messi/Lionel_Messi11.png
# ./data/cropped/Lionel_Messi/Lionel_Messi12.png
# ./data/cropped/Lionel_Messi/Lionel_Messi13.png
# ./data/cropped/Lionel_Messi/Lionel_Messi14.png
# ./data/cropped/Lionel_Messi/Lionel_Messi15.png
# ./data/cropped/Lionel_Messi/Lionel_Messi16.png
# ./data/cropped/Lionel_Messi/Lionel_Messi17.png
# ./data/cropped/Lionel_Messi/Lionel_Messi18.png
# ./data/cropped/Lionel_Messi/Lionel_Messi19.png
# ./data/cropped/Lionel_Messi/Lionel_Messi20.png
# ./data/cropped/Lionel_Messi/Lionel_Messi21.png
# ./data/cropped/Lionel_Messi/Lionel_Messi22.png
# ./data/cropped/Lionel_Messi/Lionel_Messi23.png
# ./data/cropped/Lionel_Messi/Lionel_Messi24.png
# ./data/cropped/Lionel_Messi/Lionel_Messi25.png
# ./data/cropped/Lionel_Messi/Lionel_Messi26.png
# ./data/cropped/Lionel_Messi/Lionel_Messi27.png
# ./data/cropped/Lionel_Messi/Lionel_Messi28.png
# ./data/cropped/Lionel_Messi/Lionel_Messi29.png
# ./data/cropped/Lionel_Messi/Lionel_Messi30.png
# ./data/cropped/Lionel_Messi/Lionel_Messi31.png
# ./data/cropped/Lionel_Messi/Lionel_Messi32.png
# ./data/cropped/Lionel_Messi/Lionel_Messi33.png
# ./data/cropped/Lionel_Messi/Lionel_Messi34.png
# ./data/cropped/Lionel_Messi/Lionel_Messi35.png
# ./data/cropped/Lionel_Messi/Lionel_Messi36.png
# ./data/cropped/Lionel_Messi/Lionel_Messi37.png
# ./data/cropped/Lionel_Messi/Lionel_Messi38.png
# ./data/cropped/Lionel_Messi/Lionel_Messi39.png
# ./data/cropped/Lionel_Messi/Lionel_Messi40.png
# ./data/cropped/Lionel_Messi/Lionel_Messi41.png
# ./data/cropped/Lionel_Messi/Lionel_Messi42.png
# ./data/cropped/Lionel_Messi/Lionel_Messi43.png
# ./data/cropped/Lionel_Messi/Lionel_Messi44.png
# ./data/cropped/Lionel_Messi/Lionel_Messi45.png

# %%
X,y = [],[]
for celebrity_name,training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img,(32,32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har,(32,32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
X= np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (398, 4096)

# %% [markdown]
# ### Data cleaning is done. Now we are ready to train our model

# %% [markdown]
# we will use SVM with kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state =0)
pipe = Pipeline([  ('scaler',StandardScaler())  ,  ('svc',SVC(kernel = 'rbf',C=10))  ])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.71

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        14
#            1       0.75      0.75      0.75        16
#            2       1.00      0.20      0.33         5
#            3       0.75      0.75      0.75        20
#            4       0.64      0.64      0.64        14
#            5       0.55      0.80      0.65        20
#            6       1.00      0.55      0.71        11
#
#     accuracy                           0.71       100
#    macro avg       0.79      0.65      0.67       100
# weighted avg       0.75      0.71      0.70       100

# %% [markdown]
# ### Let's use GridSearchCV to try out different models with different parameters. Goal is to come up with best model with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators ={}
import pandas as pd
for algo,mp in model_params.items():
    pipe = make_pipeline(StandardScaler(),mp['model'])
    clf = GridSearchCV(pipe,mp['params'],cv=5,return_train_score = False)
    clf.fit(X_train,y_train)
    scores.append({
        'model':algo,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_

# %%
df= pd.DataFrame(scores,columns = ['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.711186
# 1        random_forest    0.486667
# 2  logistic_regression    0.714802
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 5}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=5, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.79

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.52

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.84

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,best_clf.predict(X_test))
import seaborn as sns
plt.figure(figsize = (10,7))
sns.heatmap(cm,annot=True);
plt.xlabel('Predict')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Barack_Obama': 0,
#  'C_Ronaldo': 1,
#  'Donald_Trump': 2,
#  'Elizabeth_Olsen': 3,
#  'Gal_Gadot': 4,
#  'Jennifer_Lawrence': 5,
#  'Lionel_Messi': 6}

# %% [markdown]
# ### Save the trained model

# %%
import joblib
joblib.dump(best_clf,'save_model.pkl')
# Out:
# ['save_model.pkl']

# %%
import json
with open('class_dictionary.json','w') as f:
    f.write(json.dumps(class_dict))
